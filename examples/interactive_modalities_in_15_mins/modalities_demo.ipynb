# %% [markdown]
# ![a](res/banner.jpg)
#
# <h1 style="text-align: center;">Getting into Modalities in 15mins</h1>
#
# <hr/>
#
# **Let's train a dense model with Modalities involving the following steps:**
#
# 1. Data Preprocessing (Indexation, Tokenization)
# 2. Model Pretraining (GPT Model)
# 3. Monitoring (Weights&Biases)
#
#
# **Folder structure:**
#
# Throughout the tutorial, we will use the Jupyter Notebook `modalities_demo.ipynb` to guide us through the process. The notebook is located in the root directory of the tutorial, along with the `configs` and `data` directories. The `configs` directory contains configuration files for the model pretraining and tokenization, while the `data` directory contains subdirectories for storing checkpoints, preprocessed data, raw data, and tokenizer-related files.
#
# ```text
# └── getting_started_15mins                          # Root directory for the tutorial
#     ├── modalities_demo.ipynb                       # The Jupyter Notebook which we will be using for the tutorial.
#     ├── configs
#     │   ├── pretraining_config.yaml                 # Configuration file for the model pretraining, containing a full represe.
#     │   └── tokenization_config.yaml                # Configuration file for tokenization, specifying settings like vocabulary size, token types, etc.
#     └── data
#         ├── checkpoints                             # Directory where checkpoints (model and optimizer states saved during training) are stored.
#         │   └── <checkpoints>
#         ├── preprocessed                            # Directory containing preprocessed data that is ready for training or analysis.
#         │   └── <files>
#         ├── raw
#         │   └── fineweb_edu_num_docs_483606.jsonl   # JSONL file containing raw data for training or testing.
#         └── tokenizer
#             ├── tokenizer.json                      # JSON file defining the tokenizer model, including token mappings.
#             └── tokenizer_config.json               # Configuration file specifying additional settings for the tokenizer (e.g., special tokens, padding).
#
# ```

# %% [markdown]
# ## Prepraration steps
#
# Firstly, we need to install Modalities via pip
#
# ```bash
# pip install modalities
# ```
#
# and download the raw training data.
# We are going to use a  subset (500k documents) of the FineWeb-Edu dataset, as it is already cleaned, filtered and deduplicated.
#
# ```bash
# cd data/raw
# wget https://huggingface.co/datasets/ModalitiesTeam/FW_EDU_SUBSET_500k_docs/resolve/main/fineweb_edu_num_docs_483606.jsonl?download=true -O fineweb_edu_num_docs_483606.jsonl
# ```

# %% [markdown]
# **Disclaimer:**
#
# Don't run modalities in jupyter notebooks!

# %% [markdown]
# But this time for demonstration purposes:
#
# <img src="res/notebooks_1.png" alt="Alt text" style="width:30%;"/>
#
# <small> credits: Joel Grus - I don't like Notebooks</small>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Before training the model, we will preprocess the raw data. In the first step, we will create an index of the data that stores the starting byte position and byte length of every document. The index will be used to efficiently index the JSONL file during the tokenization in the second step.
#
# The raw JSONL dataset and has the following properties:
#
# * Subset of FineWeb-Edu (~500k documents) encoded as JSONL file
# * already cleaned, filtered and deduplicated
#
# Each line in the JSONL is a proper JSON object containing a single document.
# ```json
# {
#    "text":"What is the difference between 50 Ohm and 75 Ohm Coax? [...]",
#    "id":"<urn:uuid:57e09efe-1c29-49f8-a086-e1bb5dd552c9>",
#    "dump":"CC-MAIN-2021-39",
#    "url":"http://cablesondemandblog.com/wordpress1/2014/03/",
#    "file_path":"s3://commoncrawl/crawl-data/[...]20210918002307-00380.warc.gz",
#    "language":"en",
#    "language_score":0.9309850335121155,
#    "token_count":2355,
#    "score":3.625,
#    "int_score":4
# }
# ```
#
# While the meta data is generally interesing and can be used to further filter the dataset, we are only interested in the text field for now, providing us with the actual training data.

# %% [markdown]
# ## Indexation

# %% [markdown]
# The goal of the indexation process is to determine the starting byte position and length of each document in the raw data file.
#
# Architecturally, as shown in the diagram below, a reader process reads the raw data file line by line and writes the starting byte position and length of each document to the queue. For each line in the queue, the processor first validates the JSON object and then writes the starting byte position and length of the document to the index file.

# %% [markdown]
# <img src="res/modalities_indexation_bright.svg" alt="Alt text" style="width:80%;"/>
#
# We run the indexation with the command shown below.
#
# The `modalities data create_raw_index` command triggers the process of creating the index from the raw data.
# The `--index_path argument` specifies the location where the generated index file will be saved. In this example, the index will be stored at `data/preprocessed/fineweb_edu_num_docs_483606.idx`.
# The last part, i.e., `data/raw/fineweb_edu_num_docs_483606.jsonl` is the input file in JSONL (JSON Lines) format containing the raw data. The command will process this file to create the index.

# %%
# !modalities data create_raw_index --index_path data/preprocessed/fineweb_edu_num_docs_483606.idx \
                                               data/raw/fineweb_edu_num_docs_483606.jsonl
# Out:
# reading raw data from data/raw/fineweb_edu_num_docs_483606.jsonl
# writing index to data/preprocessed/fineweb_edu_num_docs_483606.idx
# Processed Lines: 483606it [00:18, 26703.57it/s]
# Created index of length 483606

# %% [markdown]
# ## Throughput optimized tokenization

# %% [markdown]
# Now that the we have the raw JSONL dataset indexed, we can proceed with the tokenization.
#
# In Modalities, tokenization is the process of converting raw text data into a sequence of tokens that can be used as input to the model. This is achieved by scaling up the number of processors performing the tokenization on batches of documents in parallel, as shown in the diagram below. Typically, we use one processor per CPU core to maximize throughput and adapt the queue sizes and batches sizes for optimal throughput.
#
# The processors place the tokenized documents as byte streams in the queue from which the writer reads and writes the tokenized documents to the output file.
#
# <img src="res/modalities_tokenization_bright.svg" alt="Alt text" style="width:100%;"/>
#
# The tokenized dataset file is heavily optimized for efficient indexing. As layed out in the diagram below, the header specifies the size of the data segment and size of a single token in bytes. With this information at hand, the file format is self-contained and does not need any additional information to be read. The data segment contains the concatenated byte streams of the tokenized documents.
# The documents are indexed by their starting byte position and length stored in the index segment. This allows for efficient random access to the tokenized documents in O(1) time complexity.
#
# Additionally, the shuffling of the data can be performed independently of the actual documents, as only the index can be shuffled which has a much lower memory-footprint. Internally, we implemented a numpy array-like view on top of the data segment.
#
# <img src="res/modalities_file_format_bright.svg" alt="Alt text" style="width:70%;"/>
#
#
# We define the tokenization config as printed out below. It defines the tokenizer component including all the necessary settings to make it fully reproducible. Under settings we additionally define the performance optimization settings, such as number of CPUs to use and queue sizes, as well as, the input and output file paths.

# %%
from IPython.display import Markdown, display

def display_markdown(file_path):
    with open(file_path, 'r') as file:
        code = file.read()
    display(Markdown(f'```yaml\n{code}\n```'))

# %%
tokenization_config_path = "configs/tokenization_config.yaml"
display_markdown(tokenization_config_path)
# Out:
# ```yaml
# settings:
#   src_path: data/raw/fineweb_edu_num_docs_483606.jsonl
#   dst_path: data/preprocessed/fineweb_edu_num_docs_483606.pbin
#   index_path: data/preprocessed/fineweb_edu_num_docs_483606.idx
#   jq_pattern: .text
#   num_cpus: ${node_env:num_cpus}
#   eod_token: <|endoftext|>
#   processing_batch_size: 10
#   raw_samples_queue_size: 300
#   processed_samples_queue_size: 300
#
# tokenizer:
#   component_key: tokenizer
#   variant_key: pretrained_hf_tokenizer
#   config:
#     pretrained_model_name_or_path: data/tokenizer
#     padding: false
#     truncation: false
# ```

# %%
# !modalities data pack_encoded_data configs/tokenization_config.yaml
# Out:
# Instantiated <class 'modalities.tokenization.tokenizer_wrapper.PreTrainedHFTokenizer'>: tokenizer
# Processed batches: 100%|█████████████| 483606/483606 [00:17<00:00, 27330.58it/s]

# %% [markdown]
# # Training

# %% [markdown]
# In Modalities, we scale up the training via Fully Sharded Data Parallel (FSDP), as defined in the paper [Zhao, Yanli, et al. "Pytorch fsdp: experiences on scaling fully sharded data parallel." arXiv preprint arXiv:2304.11277 (2023).](https://arxiv.org/pdf/2304.11277)
#
# **Goal:** Maximizing the token throughput during training by trading off communication overhead for a lower memory footprint.
#
# * Before training model is split into FSDP units and each FSDP unit is sharded across all ranks
# * Each rank is a data parallel process receiving only a subset of the data
# * Each rank materializes one FSDP unit at a time during the forward pass by receving the sharded weights from its peers
#
# <img src="res/fsdp_bright.svg" alt="Alt text" style="width:90%;"/>
#
#
# adopted from Zhao, Yanli, et al. "Pytorch fsdp: experiences on scaling fully sharded data parallel." arXiv preprint arXiv:2304.11277 (2023).

# %% [markdown]
# While FSDP happens under the hood of Modalities the user can still parameterize the training process via the `pretraining_config.yaml` file. In fact, the training config is specified in a way that every component during training, e.g, dataset, dataloader, model, etc., are fully reproducible. On the one hand, this leads to larger, somewhat more complex config files, however it also allows to fully reproduce the training process. Especially in the field of LLMs, where the training process is expensive, complex and involves excessive amounts of ablations, this is a crucial feature to keep track of the entire configuration of the system in a reproducible manner.
#
# The config file is shown in the print out below.

# %%
tokenization_config_path = "configs/pretraining_config.yaml"
display_markdown(tokenization_config_path)

# %% [markdown]
# Below you find the command for running the distributed training with modalities across multiple 4 GPUs on a single node. Let's break it down into its components:
#
# * `CUDA_VISIBLE_DEVICES=0,1,2,3`: This environment variable specifies which GPUs will be used for the job. In this case, GPUs with IDs 0, 1, 2, 3 are selected for training.
#
# * `torchrun`: This is a utility from PyTorch used to launch distributed training. It automatically manages multiple processes for distributed training.
#
# * `--rdzv-endpoint localhost:29515`: Specifies the rendezvous endpoint. Here, localhost is the machine's address, and 29515 is the port. The rendezvous endpoint coordinates the processes involved in distributed training.
#
# * `--nnodes 1`: Specifies the number of nodes to be used in the distributed setup. Since this is a single-node setup, 1 is used.
#
# * `--nproc_per_node 4`: This argument tells torchrun how many processes to launch on each node. In this case, 4 processes are launched per node, corresponding to the 4 GPUs (IDs 0, 1, 2, 3) specified by `CUDA_VISIBLE_DEVICES`.
#
# * `$(which modalities) run`: This part dynamically finds the path to the modalities executable and runs it. The run command triggers the main process to start the training.
#
# * `--config_file_path configs/pretraining_config.yaml`: The `--config_file_path` argument provides the path to the configuration file for the training job. In this example, the configuration is provided in `configs/pretraining_config.yaml`, which includes settings like model architecture, optimizer, dataset, dataloader and other training components.
#
#
# Once executed, the training process will start, and you will see the training logs in the terminal. The logs will include information about the training progress, such as the loss values, learning rate, and other metrics. Additionally, you can monitor the training process using Weights & Biases, which modalities automatically logs. Make sure that you are logged into your Weights & Biases account to track the training metrics.

# %%
! CUDA_VISIBLE_DEVICES=0,1,2,3 torchrun --rdzv-endpoint localhost:29515 \
                                        --nnodes 1 \
                                        --nproc_per_node 4 \
                                        $(which modalities) run --config_file_path configs/pretraining_config.yaml
# Out:
# W0906 16:14:45.871000 139806215406656 torch/distributed/run.py:757]
# W0906 16:14:45.871000 139806215406656 torch/distributed/run.py:757] *****************************************
# W0906 16:14:45.871000 139806215406656 torch/distributed/run.py:757] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0906 16:14:45.871000 139806215406656 torch/distributed/run.py:757] *****************************************
# Instantiated <class 'modalities.models.components.layer_norms.RMSLayerNorm'>: model_raw -> config -> attention_norm
# Instantiated <class 'modalities.models.components.layer_norms.RMSLayerNorm'>: model_raw -> config -> ffn_norm
# Instantiated <class 'modalities.models.components.layer_norms.RMSLayerNorm'>: model_raw -> config -> lm_head_norm
# Instantiated <class 'modalities.models.gpt2.gpt2_model.GPT2LLM'>: model_raw
# Instantiated <class 'modalities.nn.model_initialization.composed_initialization.ModelInitializerWrapper'>: model -> config -> model_initializer
# Instantiated <class 'modalities.models.gpt2.gpt2_model.GPT2LLM'>: model
#
# Wrapped layer classes: [<class 'modalities.models.gpt2.gpt2_model.GPT2Block'>]
#
# Instantiated <class 'torch.distributed.fsdp.fully_sharded_data_parallel.FullyShardedDataParallel'>: wrapped_model
# => optimizer groups:
# linear (28 modules with 122,880 parameters): weight_decay = 0.1
# embedding (1 modules with 1,609,792 parameters): weight_decay = 0.0
# layernorm (10 modules with 1,024 parameters): weight_decay = 0.0
# => all (39 modules with 1,733,696 parameters)
# Instantiated <class 'torch.optim.adamw.AdamW'>: optimizer
# Instantiated <class 'torch.optim.lr_scheduler.OneCycleLR'>: scheduler
# Instantiated <class 'modalities.loss_functions.CLMCrossEntropyLoss'>: loss_fn
# Instantiated <class 'modalities.dataloader.dataset.PackedMemMapDatasetContinuous'>: train_dataset
# Instantiated <class 'torch.utils.data.distributed.DistributedSampler'>: train_dataloader -> config -> batch_sampler -> config -> sampler
# Instantiated <class 'torch.utils.data.sampler.BatchSampler'>: train_dataloader -> config -> batch_sampler
# Instantiated <class 'modalities.models.gpt2.collator.GPT2LLMCollateFn'>: collate_fn
# Instantiated <class 'modalities.dataloader.dataloader.LLMDataLoader'>: train_dataloader
# Instantiated <class 'modalities.logging_broker.subscriber_impl.batch_progress_subscriber.DummyProgressSubscriber'>: batch_progress_subscriber
# wandb: Currently logged in as: max-luebbering (modalities). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.17.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.16.2
# wandb: Run data is saved locally in /raid/s3/opengptx/max_lue/modalities/examples/interactive_modalities_in_15_mins/wandb_storage/wandb/run-20240906_161502-q1a14g30
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2024-09-06__16-14-48_7d9fc15e
# wandb: ⭐️ View project at https://wandb.ai/modalities/ai_24_demo
# wandb: 🚀 View run at https://wandb.ai/modalities/ai_24_demo/runs/q1a14g30
# Instantiated <class 'modalities.logging_broker.subscriber_impl.results_subscriber.WandBEvaluationResultSubscriber'>: evaluation_subscriber
# Instantiated <class 'modalities.checkpointing.checkpoint_saving_strategies.SaveKMostRecentCheckpointsStrategy'>: checkpoint_saving -> config -> checkpoint_saving_strategy
# Instantiated <class 'function'>: checkpoint_saving -> config -> checkpoint_saving_execution -> config -> get_num_tokens_from_num_steps_callable
# Instantiated <class 'modalities.checkpointing.fsdp.fsdp_checkpoint_saving.FSDPCheckpointSaving'>: checkpoint_saving -> config -> checkpoint_saving_execution
# Instantiated <class 'modalities.checkpointing.checkpoint_saving.CheckpointSaving'>: checkpoint_saving
# Instantiated <class 'modalities.training.gradient_clipping.fsdp_gradient_clipper.FSDPGradientClipper'>: gradient_clipper
# Initialize Model at 2024-09-06 16:15:08.142419.
# Model initialized at 2024-09-06 16:15:08.145587.
# Start model training at 2024-09-06 16:15:08.145660.
# step: 5 | train samples/s: 736.0 | train mfu: 0.01 | lr mean: 0.000377 | train loss avg: 10.81 | train loss last: 10.75 | consumed tokens: 327680 | grad norm avg: 2.19 | grad norm last: 2.23 |
# step: 10 | train samples/s: 3595.5 | train mfu: 0.03 | lr mean: 0.000600 | train loss avg: 10.56 | train loss last: 10.44 | consumed tokens: 655360 | grad norm avg: 1.29 | grad norm last: 0.98 |
# step: 15 | train samples/s: 8532.4 | train mfu: 0.07 | lr mean: 0.000600 | train loss avg: 10.18 | train loss last: 10.00 | consumed tokens: 983040 | grad norm avg: 1.00 | grad norm last: 1.00 |
# step: 20 | train samples/s: 8593.4 | train mfu: 0.07 | lr mean: 0.000600 | train loss avg: 9.74 | train loss last: 9.56 | consumed tokens: 1310720 | grad norm avg: 1.00 | grad norm last: 1.01 |
# step: 25 | train samples/s: 8595.0 | train mfu: 0.07 | lr mean: 0.000600 | train loss avg: 9.35 | train loss last: 9.20 | consumed tokens: 1638400 | grad norm avg: 1.02 | grad norm last: 1.01 |
# step: 30 | train samples/s: 8600.8 | train mfu: 0.07 | lr mean: 0.000599 | train loss avg: 8.98 | train loss last: 8.84 | consumed tokens: 1966080 | grad norm avg: 1.01 | grad norm last: 1.00 |
# step: 35 | train samples/s: 8629.7 | train mfu: 0.08 | lr mean: 0.000599 | train loss avg: 8.69 | train loss last: 8.56 | consumed tokens: 2293760 | grad norm avg: 1.01 | grad norm last: 1.00 |
# step: 40 | train samples/s: 8616.6 | train mfu: 0.07 | lr mean: 0.000599 | train loss avg: 8.41 | train loss last: 8.31 | consumed tokens: 2621440 | grad norm avg: 0.99 | grad norm last: 0.99 |
# step: 45 | train samples/s: 8542.1 | train mfu: 0.07 | lr mean: 0.000598 | train loss avg: 8.19 | train loss last: 8.14 | consumed tokens: 2949120 | grad norm avg: 0.96 | grad norm last: 0.94 |
# step: 50 | train samples/s: 8574.2 | train mfu: 0.07 | lr mean: 0.000598 | train loss avg: 8.01 | train loss last: 7.91 | consumed tokens: 3276800 | grad norm avg: 0.92 | grad norm last: 0.93 |
# step: 55 | train samples/s: 8353.2 | train mfu: 0.07 | lr mean: 0.000597 | train loss avg: 7.85 | train loss last: 7.78 | consumed tokens: 3604480 | grad norm avg: 0.92 | grad norm last: 0.85 |
# step: 60 | train samples/s: 8503.3 | train mfu: 0.07 | lr mean: 0.000596 | train loss avg: 7.75 | train loss last: 7.70 | consumed tokens: 3932160 | grad norm avg: 0.80 | grad norm last: 0.72 |
# step: 65 | train samples/s: 8582.4 | train mfu: 0.07 | lr mean: 0.000596 | train loss avg: 7.61 | train loss last: 7.55 | consumed tokens: 4259840 | grad norm avg: 0.70 | grad norm last: 0.61 |
# step: 70 | train samples/s: 8599.9 | train mfu: 0.07 | lr mean: 0.000595 | train loss avg: 7.51 | train loss last: 7.52 | consumed tokens: 4587520 | grad norm avg: 0.70 | grad norm last: 0.74 |
# step: 75 | train samples/s: 8567.2 | train mfu: 0.07 | lr mean: 0.000594 | train loss avg: 7.43 | train loss last: 7.41 | consumed tokens: 4915200 | grad norm avg: 0.63 | grad norm last: 0.44 |
# step: 80 | train samples/s: 8636.1 | train mfu: 0.08 | lr mean: 0.000593 | train loss avg: 7.37 | train loss last: 7.38 | consumed tokens: 5242880 | grad norm avg: 0.74 | grad norm last: 0.91 |
# step: 85 | train samples/s: 8620.8 | train mfu: 0.07 | lr mean: 0.000592 | train loss avg: 7.29 | train loss last: 7.23 | consumed tokens: 5570560 | grad norm avg: 0.56 | grad norm last: 0.60 |
# step: 90 | train samples/s: 8604.2 | train mfu: 0.07 | lr mean: 0.000591 | train loss avg: 7.25 | train loss last: 7.23 | consumed tokens: 5898240 | grad norm avg: 0.68 | grad norm last: 0.58 |
# step: 95 | train samples/s: 8569.4 | train mfu: 0.07 | lr mean: 0.000590 | train loss avg: 7.18 | train loss last: 7.12 | consumed tokens: 6225920 | grad norm avg: 0.86 | grad norm last: 0.90 |
# step: 100 | train samples/s: 8520.1 | train mfu: 0.07 | lr mean: 0.000589 | train loss avg: 7.12 | train loss last: 7.09 | consumed tokens: 6553600 | grad norm avg: 0.59 | grad norm last: 0.62 |
# step: 105 | train samples/s: 8335.3 | train mfu: 0.07 | lr mean: 0.000588 | train loss avg: 7.07 | train loss last: 7.04 | consumed tokens: 6881280 | grad norm avg: 0.57 | grad norm last: 0.36 |
# step: 110 | train samples/s: 8629.4 | train mfu: 0.08 | lr mean: 0.000586 | train loss avg: 7.00 | train loss last: 6.95 | consumed tokens: 7208960 | grad norm avg: 0.41 | grad norm last: 0.53 |
# step: 115 | train samples/s: 8307.4 | train mfu: 0.07 | lr mean: 0.000585 | train loss avg: 6.97 | train loss last: 6.95 | consumed tokens: 7536640 | grad norm avg: 0.87 | grad norm last: 0.95 |
# step: 120 | train samples/s: 8407.7 | train mfu: 0.07 | lr mean: 0.000583 | train loss avg: 6.93 | train loss last: 6.89 | consumed tokens: 7864320 | grad norm avg: 0.60 | grad norm last: 0.50 |
# step: 125 | train samples/s: 8484.3 | train mfu: 0.07 | lr mean: 0.000582 | train loss avg: 6.87 | train loss last: 6.83 | consumed tokens: 8192000 | grad norm avg: 0.51 | grad norm last: 0.70 |
# step: 130 | train samples/s: 8498.5 | train mfu: 0.07 | lr mean: 0.000580 | train loss avg: 6.84 | train loss last: 6.82 | consumed tokens: 8519680 | grad norm avg: 0.62 | grad norm last: 0.73 |
# step: 135 | train samples/s: 8558.5 | train mfu: 0.07 | lr mean: 0.000579 | train loss avg: 6.78 | train loss last: 6.77 | consumed tokens: 8847360 | grad norm avg: 0.61 | grad norm last: 0.53 |
# step: 140 | train samples/s: 8506.1 | train mfu: 0.07 | lr mean: 0.000577 | train loss avg: 6.75 | train loss last: 6.67 | consumed tokens: 9175040 | grad norm avg: 0.64 | grad norm last: 0.70 |
# step: 145 | train samples/s: 8577.2 | train mfu: 0.07 | lr mean: 0.000575 | train loss avg: 6.74 | train loss last: 6.71 | consumed tokens: 9502720 | grad norm avg: 0.63 | grad norm last: 0.56 |
# step: 150 | train samples/s: 8602.9 | train mfu: 0.07 | lr mean: 0.000573 | train loss avg: 6.69 | train loss last: 6.67 | consumed tokens: 9830400 | grad norm avg: 0.67 | grad norm last: 0.87 |
# step: 155 | train samples/s: 8457.2 | train mfu: 0.07 | lr mean: 0.000572 | train loss avg: 6.67 | train loss last: 6.65 | consumed tokens: 10158080 | grad norm avg: 0.56 | grad norm last: 0.57 |
# step: 160 | train samples/s: 8579.7 | train mfu: 0.07 | lr mean: 0.000570 | train loss avg: 6.62 | train loss last: 6.55 | consumed tokens: 10485760 | grad norm avg: 0.50 | grad norm last: 0.76 |
# step: 165 | train samples/s: 8555.7 | train mfu: 0.07 | lr mean: 0.000568 | train loss avg: 6.62 | train loss last: 6.62 | consumed tokens: 10813440 | grad norm avg: 0.83 | grad norm last: 0.99 |
# step: 170 | train samples/s: 8558.3 | train mfu: 0.07 | lr mean: 0.000566 | train loss avg: 6.59 | train loss last: 6.59 | consumed tokens: 11141120 | grad norm avg: 0.65 | grad norm last: 0.56 |
# step: 175 | train samples/s: 8598.3 | train mfu: 0.07 | lr mean: 0.000563 | train loss avg: 6.59 | train loss last: 6.55 | consumed tokens: 11468800 | grad norm avg: 0.69 | grad norm last: 0.96 |
# step: 180 | train samples/s: 8404.8 | train mfu: 0.07 | lr mean: 0.000561 | train loss avg: 6.53 | train loss last: 6.52 | consumed tokens: 11796480 | grad norm avg: 0.73 | grad norm last: 0.54 |
# step: 185 | train samples/s: 8584.0 | train mfu: 0.07 | lr mean: 0.000559 | train loss avg: 6.54 | train loss last: 6.56 | consumed tokens: 12124160 | grad norm avg: 0.73 | grad norm last: 0.78 |
# step: 190 | train samples/s: 8519.4 | train mfu: 0.07 | lr mean: 0.000557 | train loss avg: 6.50 | train loss last: 6.52 | consumed tokens: 12451840 | grad norm avg: 0.70 | grad norm last: 0.50 |
# step: 195 | train samples/s: 8471.9 | train mfu: 0.07 | lr mean: 0.000554 | train loss avg: 6.51 | train loss last: 6.47 | consumed tokens: 12779520 | grad norm avg: 0.78 | grad norm last: 1.13 |
# step: 200 | train samples/s: 8613.4 | train mfu: 0.07 | lr mean: 0.000552 | train loss avg: 6.47 | train loss last: 6.45 | consumed tokens: 13107200 | grad norm avg: 0.82 | grad norm last: 0.94 |
# step: 205 | train samples/s: 8412.2 | train mfu: 0.07 | lr mean: 0.000549 | train loss avg: 6.46 | train loss last: 6.45 | consumed tokens: 13434880 | grad norm avg: 0.83 | grad norm last: 0.78 |
# step: 210 | train samples/s: 8630.5 | train mfu: 0.08 | lr mean: 0.000547 | train loss avg: 6.45 | train loss last: 6.49 | consumed tokens: 13762560 | grad norm avg: 0.67 | grad norm last: 0.60 |
# step: 215 | train samples/s: 8629.9 | train mfu: 0.08 | lr mean: 0.000544 | train loss avg: 6.42 | train loss last: 6.41 | consumed tokens: 14090240 | grad norm avg: 0.89 | grad norm last: 1.35 |
# step: 220 | train samples/s: 2346.3 | train mfu: 0.02 | lr mean: 0.000542 | train loss avg: 6.39 | train loss last: 6.42 | consumed tokens: 14417920 | grad norm avg: 0.91 | grad norm last: 0.74 |
# step: 225 | train samples/s: 8584.4 | train mfu: 0.07 | lr mean: 0.000539 | train loss avg: 6.37 | train loss last: 6.40 | consumed tokens: 14745600 | grad norm avg: 0.95 | grad norm last: 0.81 |
# step: 230 | train samples/s: 8600.9 | train mfu: 0.07 | lr mean: 0.000536 | train loss avg: 6.33 | train loss last: 6.35 | consumed tokens: 15073280 | grad norm avg: 0.79 | grad norm last: 0.84 |
# step: 235 | train samples/s: 8614.2 | train mfu: 0.07 | lr mean: 0.000533 | train loss avg: 6.33 | train loss last: 6.25 | consumed tokens: 15400960 | grad norm avg: 0.74 | grad norm last: 0.74 |
# step: 240 | train samples/s: 8599.8 | train mfu: 0.07 | lr mean: 0.000531 | train loss avg: 6.35 | train loss last: 6.34 | consumed tokens: 15728640 | grad norm avg: 0.77 | grad norm last: 0.64 |
# step: 245 | train samples/s: 8546.6 | train mfu: 0.07 | lr mean: 0.000528 | train loss avg: 6.32 | train loss last: 6.32 | consumed tokens: 16056320 | grad norm avg: 0.66 | grad norm last: 0.82 |
# step: 250 | train samples/s: 8344.0 | train mfu: 0.07 | lr mean: 0.000525 | train loss avg: 6.31 | train loss last: 6.30 | consumed tokens: 16384000 | grad norm avg: 0.93 | grad norm last: 0.76 |
# step: 255 | train samples/s: 8196.8 | train mfu: 0.07 | lr mean: 0.000522 | train loss avg: 6.32 | train loss last: 6.38 | consumed tokens: 16711680 | grad norm avg: 0.89 | grad norm last: 0.79 |
# step: 260 | train samples/s: 8587.7 | train mfu: 0.07 | lr mean: 0.000519 | train loss avg: 6.28 | train loss last: 6.28 | consumed tokens: 17039360 | grad norm avg: 1.07 | grad norm last: 0.73 |
# step: 265 | train samples/s: 8564.2 | train mfu: 0.07 | lr mean: 0.000516 | train loss avg: 6.26 | train loss last: 6.24 | consumed tokens: 17367040 | grad norm avg: 1.10 | grad norm last: 0.90 |
# step: 270 | train samples/s: 8582.7 | train mfu: 0.07 | lr mean: 0.000513 | train loss avg: 6.22 | train loss last: 6.23 | consumed tokens: 17694720 | grad norm avg: 0.92 | grad norm last: 0.88 |
# step: 275 | train samples/s: 8466.8 | train mfu: 0.07 | lr mean: 0.000509 | train loss avg: 6.23 | train loss last: 6.21 | consumed tokens: 18022400 | grad norm avg: 0.85 | grad norm last: 1.11 |
# step: 280 | train samples/s: 8508.7 | train mfu: 0.07 | lr mean: 0.000506 | train loss avg: 6.21 | train loss last: 6.24 | consumed tokens: 18350080 | grad norm avg: 0.83 | grad norm last: 0.89 |
# step: 285 | train samples/s: 8595.5 | train mfu: 0.07 | lr mean: 0.000503 | train loss avg: 6.21 | train loss last: 6.21 | consumed tokens: 18677760 | grad norm avg: 0.82 | grad norm last: 1.00 |
# step: 290 | train samples/s: 8669.3 | train mfu: 0.08 | lr mean: 0.000500 | train loss avg: 6.18 | train loss last: 6.18 | consumed tokens: 19005440 | grad norm avg: 0.81 | grad norm last: 0.64 |
# step: 295 | train samples/s: 8586.9 | train mfu: 0.07 | lr mean: 0.000496 | train loss avg: 6.19 | train loss last: 6.19 | consumed tokens: 19333120 | grad norm avg: 0.78 | grad norm last: 0.74 |
# step: 300 | train samples/s: 8502.1 | train mfu: 0.07 | lr mean: 0.000493 | train loss avg: 6.18 | train loss last: 6.20 | consumed tokens: 19660800 | grad norm avg: 0.72 | grad norm last: 0.71 |
# step: 305 | train samples/s: 8253.1 | train mfu: 0.07 | lr mean: 0.000489 | train loss avg: 6.18 | train loss last: 6.16 | consumed tokens: 19988480 | grad norm avg: 0.98 | grad norm last: 1.01 |
# step: 310 | train samples/s: 8629.9 | train mfu: 0.08 | lr mean: 0.000486 | train loss avg: 6.16 | train loss last: 6.18 | consumed tokens: 20316160 | grad norm avg: 0.91 | grad norm last: 1.09 |
# step: 315 | train samples/s: 8475.9 | train mfu: 0.07 | lr mean: 0.000482 | train loss avg: 6.15 | train loss last: 6.14 | consumed tokens: 20643840 | grad norm avg: 0.92 | grad norm last: 1.09 |
# step: 320 | train samples/s: 8628.4 | train mfu: 0.08 | lr mean: 0.000479 | train loss avg: 6.14 | train loss last: 6.13 | consumed tokens: 20971520 | grad norm avg: 0.97 | grad norm last: 1.15 |
# step: 325 | train samples/s: 8512.0 | train mfu: 0.07 | lr mean: 0.000475 | train loss avg: 6.13 | train loss last: 6.12 | consumed tokens: 21299200 | grad norm avg: 1.04 | grad norm last: 0.99 |
# step: 330 | train samples/s: 8640.9 | train mfu: 0.08 | lr mean: 0.000472 | train loss avg: 6.11 | train loss last: 6.10 | consumed tokens: 21626880 | grad norm avg: 0.94 | grad norm last: 1.02 |
# step: 335 | train samples/s: 8565.1 | train mfu: 0.07 | lr mean: 0.000468 | train loss avg: 6.11 | train loss last: 6.05 | consumed tokens: 21954560 | grad norm avg: 0.81 | grad norm last: 0.71 |
# step: 340 | train samples/s: 8651.3 | train mfu: 0.08 | lr mean: 0.000464 | train loss avg: 6.10 | train loss last: 6.10 | consumed tokens: 22282240 | grad norm avg: 0.75 | grad norm last: 0.70 |
# step: 345 | train samples/s: 8620.8 | train mfu: 0.07 | lr mean: 0.000461 | train loss avg: 6.07 | train loss last: 6.06 | consumed tokens: 22609920 | grad norm avg: 0.72 | grad norm last: 0.64 |
# step: 350 | train samples/s: 8680.3 | train mfu: 0.08 | lr mean: 0.000457 | train loss avg: 6.09 | train loss last: 6.10 | consumed tokens: 22937600 | grad norm avg: 0.89 | grad norm last: 1.03 |
# step: 355 | train samples/s: 8361.5 | train mfu: 0.07 | lr mean: 0.000453 | train loss avg: 6.06 | train loss last: 6.07 | consumed tokens: 23265280 | grad norm avg: 0.83 | grad norm last: 0.67 |
# step: 360 | train samples/s: 8677.5 | train mfu: 0.08 | lr mean: 0.000449 | train loss avg: 6.06 | train loss last: 6.06 | consumed tokens: 23592960 | grad norm avg: 0.80 | grad norm last: 0.80 |
# step: 365 | train samples/s: 8636.0 | train mfu: 0.08 | lr mean: 0.000445 | train loss avg: 6.05 | train loss last: 6.07 | consumed tokens: 23920640 | grad norm avg: 0.86 | grad norm last: 0.95 |
# step: 370 | train samples/s: 8660.8 | train mfu: 0.08 | lr mean: 0.000441 | train loss avg: 6.04 | train loss last: 6.01 | consumed tokens: 24248320 | grad norm avg: 0.65 | grad norm last: 0.66 |
# step: 375 | train samples/s: 8611.0 | train mfu: 0.07 | lr mean: 0.000437 | train loss avg: 6.04 | train loss last: 6.05 | consumed tokens: 24576000 | grad norm avg: 0.70 | grad norm last: 0.77 |
# step: 380 | train samples/s: 8658.9 | train mfu: 0.08 | lr mean: 0.000434 | train loss avg: 6.03 | train loss last: 6.06 | consumed tokens: 24903680 | grad norm avg: 0.76 | grad norm last: 0.87 |
# step: 385 | train samples/s: 8637.1 | train mfu: 0.08 | lr mean: 0.000430 | train loss avg: 6.05 | train loss last: 6.02 | consumed tokens: 25231360 | grad norm avg: 0.81 | grad norm last: 0.73 |
# step: 390 | train samples/s: 8620.6 | train mfu: 0.07 | lr mean: 0.000426 | train loss avg: 6.03 | train loss last: 6.03 | consumed tokens: 25559040 | grad norm avg: 0.96 | grad norm last: 1.26 |
# step: 395 | train samples/s: 8578.4 | train mfu: 0.07 | lr mean: 0.000422 | train loss avg: 6.04 | train loss last: 6.09 | consumed tokens: 25886720 | grad norm avg: 0.96 | grad norm last: 0.94 |
# step: 400 | train samples/s: 8627.0 | train mfu: 0.08 | lr mean: 0.000417 | train loss avg: 6.00 | train loss last: 6.00 | consumed tokens: 26214400 | grad norm avg: 0.70 | grad norm last: 0.67 |
# step: 405 | train samples/s: 8123.0 | train mfu: 0.07 | lr mean: 0.000413 | train loss avg: 5.98 | train loss last: 6.02 | consumed tokens: 26542080 | grad norm avg: 0.67 | grad norm last: 0.70 |
# step: 410 | train samples/s: 8594.0 | train mfu: 0.07 | lr mean: 0.000409 | train loss avg: 5.98 | train loss last: 5.94 | consumed tokens: 26869760 | grad norm avg: 0.73 | grad norm last: 0.61 |
# step: 415 | train samples/s: 8637.6 | train mfu: 0.08 | lr mean: 0.000405 | train loss avg: 5.98 | train loss last: 5.99 | consumed tokens: 27197440 | grad norm avg: 0.78 | grad norm last: 0.79 |
# step: 420 | train samples/s: 8672.8 | train mfu: 0.08 | lr mean: 0.000401 | train loss avg: 5.96 | train loss last: 5.95 | consumed tokens: 27525120 | grad norm avg: 0.78 | grad norm last: 0.77 |
# step: 425 | train samples/s: 8537.4 | train mfu: 0.07 | lr mean: 0.000397 | train loss avg: 5.96 | train loss last: 5.98 | consumed tokens: 27852800 | grad norm avg: 0.71 | grad norm last: 0.68 |
# step: 430 | train samples/s: 8644.9 | train mfu: 0.08 | lr mean: 0.000393 | train loss avg: 5.96 | train loss last: 5.93 | consumed tokens: 28180480 | grad norm avg: 0.83 | grad norm last: 0.58 |
# step: 435 | train samples/s: 8632.2 | train mfu: 0.08 | lr mean: 0.000389 | train loss avg: 5.95 | train loss last: 5.92 | consumed tokens: 28508160 | grad norm avg: 0.72 | grad norm last: 0.74 |
# step: 440 | train samples/s: 8603.9 | train mfu: 0.07 | lr mean: 0.000384 | train loss avg: 5.94 | train loss last: 5.97 | consumed tokens: 28835840 | grad norm avg: 0.84 | grad norm last: 1.00 |
# step: 445 | train samples/s: 8570.4 | train mfu: 0.07 | lr mean: 0.000380 | train loss avg: 5.96 | train loss last: 5.90 | consumed tokens: 29163520 | grad norm avg: 0.88 | grad norm last: 0.86 |
# step: 450 | train samples/s: 8654.9 | train mfu: 0.08 | lr mean: 0.000376 | train loss avg: 5.94 | train loss last: 5.96 | consumed tokens: 29491200 | grad norm avg: 0.80 | grad norm last: 0.88 |
# step: 455 | train samples/s: 8418.7 | train mfu: 0.07 | lr mean: 0.000372 | train loss avg: 5.91 | train loss last: 5.92 | consumed tokens: 29818880 | grad norm avg: 0.77 | grad norm last: 0.80 |
# step: 460 | train samples/s: 8670.5 | train mfu: 0.08 | lr mean: 0.000368 | train loss avg: 5.93 | train loss last: 5.95 | consumed tokens: 30146560 | grad norm avg: 0.88 | grad norm last: 1.07 |
# step: 465 | train samples/s: 8673.6 | train mfu: 0.08 | lr mean: 0.000363 | train loss avg: 5.92 | train loss last: 5.91 | consumed tokens: 30474240 | grad norm avg: 0.84 | grad norm last: 0.86 |
# step: 470 | train samples/s: 8697.1 | train mfu: 0.08 | lr mean: 0.000359 | train loss avg: 5.92 | train loss last: 5.95 | consumed tokens: 30801920 | grad norm avg: 0.84 | grad norm last: 0.78 |
# step: 475 | train samples/s: 8689.7 | train mfu: 0.08 | lr mean: 0.000355 | train loss avg: 5.92 | train loss last: 5.95 | consumed tokens: 31129600 | grad norm avg: 0.73 | grad norm last: 0.58 |
# step: 480 | train samples/s: 8611.2 | train mfu: 0.07 | lr mean: 0.000351 | train loss avg: 5.91 | train loss last: 5.93 | consumed tokens: 31457280 | grad norm avg: 0.73 | grad norm last: 0.86 |
# step: 485 | train samples/s: 8725.6 | train mfu: 0.08 | lr mean: 0.000346 | train loss avg: 5.89 | train loss last: 5.90 | consumed tokens: 31784960 | grad norm avg: 0.78 | grad norm last: 0.73 |
# step: 490 | train samples/s: 8681.7 | train mfu: 0.08 | lr mean: 0.000342 | train loss avg: 5.93 | train loss last: 5.92 | consumed tokens: 32112640 | grad norm avg: 0.77 | grad norm last: 0.78 |
# step: 495 | train samples/s: 8715.0 | train mfu: 0.08 | lr mean: 0.000338 | train loss avg: 5.89 | train loss last: 5.86 | consumed tokens: 32440320 | grad norm avg: 0.72 | grad norm last: 0.73 |
# step: 500 | train samples/s: 8627.4 | train mfu: 0.08 | lr mean: 0.000333 | train loss avg: 5.90 | train loss last: 5.87 | consumed tokens: 32768000 | grad norm avg: 0.80 | grad norm last: 0.80 |
# step: 505 | train samples/s: 8469.0 | train mfu: 0.07 | lr mean: 0.000329 | train loss avg: 5.90 | train loss last: 5.88 | consumed tokens: 33095680 | grad norm avg: 0.86 | grad norm last: 0.95 |
# step: 510 | train samples/s: 8690.2 | train mfu: 0.08 | lr mean: 0.000325 | train loss avg: 5.88 | train loss last: 5.89 | consumed tokens: 33423360 | grad norm avg: 0.80 | grad norm last: 0.78 |
# step: 515 | train samples/s: 8029.0 | train mfu: 0.07 | lr mean: 0.000321 | train loss avg: 5.85 | train loss last: 5.88 | consumed tokens: 33751040 | grad norm avg: 0.73 | grad norm last: 0.81 |
# step: 520 | train samples/s: 8718.1 | train mfu: 0.08 | lr mean: 0.000316 | train loss avg: 5.85 | train loss last: 5.86 | consumed tokens: 34078720 | grad norm avg: 0.72 | grad norm last: 0.80 |
# step: 525 | train samples/s: 8659.4 | train mfu: 0.08 | lr mean: 0.000312 | train loss avg: 5.87 | train loss last: 5.89 | consumed tokens: 34406400 | grad norm avg: 0.75 | grad norm last: 0.76 |
# step: 530 | train samples/s: 8649.1 | train mfu: 0.08 | lr mean: 0.000308 | train loss avg: 5.87 | train loss last: 5.86 | consumed tokens: 34734080 | grad norm avg: 0.70 | grad norm last: 0.70 |
# step: 535 | train samples/s: 8561.7 | train mfu: 0.07 | lr mean: 0.000303 | train loss avg: 5.83 | train loss last: 5.81 | consumed tokens: 35061760 | grad norm avg: 0.70 | grad norm last: 0.80 |
# step: 540 | train samples/s: 8618.1 | train mfu: 0.07 | lr mean: 0.000299 | train loss avg: 5.87 | train loss last: 5.84 | consumed tokens: 35389440 | grad norm avg: 0.72 | grad norm last: 0.65 |
# step: 545 | train samples/s: 8664.8 | train mfu: 0.08 | lr mean: 0.000295 | train loss avg: 5.84 | train loss last: 5.84 | consumed tokens: 35717120 | grad norm avg: 0.67 | grad norm last: 0.70 |
# step: 550 | train samples/s: 8679.6 | train mfu: 0.08 | lr mean: 0.000291 | train loss avg: 5.82 | train loss last: 5.77 | consumed tokens: 36044800 | grad norm avg: 0.69 | grad norm last: 0.70 |
# step: 555 | train samples/s: 8321.3 | train mfu: 0.07 | lr mean: 0.000286 | train loss avg: 5.83 | train loss last: 5.84 | consumed tokens: 36372480 | grad norm avg: 0.72 | grad norm last: 0.67 |
# step: 560 | train samples/s: 8638.6 | train mfu: 0.08 | lr mean: 0.000282 | train loss avg: 5.82 | train loss last: 5.81 | consumed tokens: 36700160 | grad norm avg: 0.66 | grad norm last: 0.58 |
# step: 565 | train samples/s: 8506.3 | train mfu: 0.07 | lr mean: 0.000278 | train loss avg: 5.82 | train loss last: 5.85 | consumed tokens: 37027840 | grad norm avg: 0.66 | grad norm last: 0.67 |
# step: 570 | train samples/s: 8644.9 | train mfu: 0.08 | lr mean: 0.000274 | train loss avg: 5.82 | train loss last: 5.82 | consumed tokens: 37355520 | grad norm avg: 0.76 | grad norm last: 0.86 |
# step: 575 | train samples/s: 8453.6 | train mfu: 0.07 | lr mean: 0.000270 | train loss avg: 5.80 | train loss last: 5.76 | consumed tokens: 37683200 | grad norm avg: 0.64 | grad norm last: 0.69 |
# step: 580 | train samples/s: 8508.2 | train mfu: 0.07 | lr mean: 0.000266 | train loss avg: 5.81 | train loss last: 5.80 | consumed tokens: 38010880 | grad norm avg: 0.75 | grad norm last: 0.75 |
# step: 585 | train samples/s: 8589.4 | train mfu: 0.07 | lr mean: 0.000261 | train loss avg: 5.82 | train loss last: 5.83 | consumed tokens: 38338560 | grad norm avg: 0.79 | grad norm last: 0.81 |
# step: 590 | train samples/s: 8545.1 | train mfu: 0.07 | lr mean: 0.000257 | train loss avg: 5.79 | train loss last: 5.78 | consumed tokens: 38666240 | grad norm avg: 0.74 | grad norm last: 0.63 |
# step: 595 | train samples/s: 8453.6 | train mfu: 0.07 | lr mean: 0.000253 | train loss avg: 5.81 | train loss last: 5.80 | consumed tokens: 38993920 | grad norm avg: 0.78 | grad norm last: 0.65 |
# step: 600 | train samples/s: 4140.3 | train mfu: 0.04 | lr mean: 0.000249 | train loss avg: 5.77 | train loss last: 5.79 | consumed tokens: 39321600 | grad norm avg: 0.77 | grad norm last: 0.84 |
# step: 605 | train samples/s: 8401.4 | train mfu: 0.07 | lr mean: 0.000245 | train loss avg: 5.80 | train loss last: 5.76 | consumed tokens: 39649280 | grad norm avg: 0.82 | grad norm last: 0.94 |
# step: 610 | train samples/s: 8647.9 | train mfu: 0.08 | lr mean: 0.000241 | train loss avg: 5.77 | train loss last: 5.75 | consumed tokens: 39976960 | grad norm avg: 0.79 | grad norm last: 0.67 |
# step: 615 | train samples/s: 8651.0 | train mfu: 0.08 | lr mean: 0.000237 | train loss avg: 5.79 | train loss last: 5.84 | consumed tokens: 40304640 | grad norm avg: 0.80 | grad norm last: 0.72 |
# step: 620 | train samples/s: 8657.3 | train mfu: 0.08 | lr mean: 0.000233 | train loss avg: 5.78 | train loss last: 5.79 | consumed tokens: 40632320 | grad norm avg: 0.69 | grad norm last: 0.71 |
# step: 625 | train samples/s: 8635.8 | train mfu: 0.08 | lr mean: 0.000229 | train loss avg: 5.76 | train loss last: 5.79 | consumed tokens: 40960000 | grad norm avg: 0.65 | grad norm last: 0.65 |
# step: 630 | train samples/s: 8669.1 | train mfu: 0.08 | lr mean: 0.000225 | train loss avg: 5.75 | train loss last: 5.75 | consumed tokens: 41287680 | grad norm avg: 0.68 | grad norm last: 0.61 |
# step: 635 | train samples/s: 8716.3 | train mfu: 0.08 | lr mean: 0.000221 | train loss avg: 5.79 | train loss last: 5.79 | consumed tokens: 41615360 | grad norm avg: 0.72 | grad norm last: 0.77 |
# step: 640 | train samples/s: 8671.7 | train mfu: 0.08 | lr mean: 0.000217 | train loss avg: 5.77 | train loss last: 5.77 | consumed tokens: 41943040 | grad norm avg: 0.72 | grad norm last: 0.66 |
# step: 645 | train samples/s: 8328.0 | train mfu: 0.07 | lr mean: 0.000213 | train loss avg: 5.77 | train loss last: 5.75 | consumed tokens: 42270720 | grad norm avg: 0.74 | grad norm last: 0.70 |
# step: 650 | train samples/s: 8040.2 | train mfu: 0.07 | lr mean: 0.000209 | train loss avg: 5.77 | train loss last: 5.77 | consumed tokens: 42598400 | grad norm avg: 0.72 | grad norm last: 0.81 |
# step: 655 | train samples/s: 8488.0 | train mfu: 0.07 | lr mean: 0.000206 | train loss avg: 5.76 | train loss last: 5.72 | consumed tokens: 42926080 | grad norm avg: 0.79 | grad norm last: 0.71 |
# step: 660 | train samples/s: 8710.1 | train mfu: 0.08 | lr mean: 0.000202 | train loss avg: 5.76 | train loss last: 5.76 | consumed tokens: 43253760 | grad norm avg: 0.73 | grad norm last: 0.69 |
# step: 665 | train samples/s: 8678.2 | train mfu: 0.08 | lr mean: 0.000198 | train loss avg: 5.75 | train loss last: 5.71 | consumed tokens: 43581440 | grad norm avg: 0.73 | grad norm last: 0.81 |
# step: 670 | train samples/s: 8646.1 | train mfu: 0.08 | lr mean: 0.000194 | train loss avg: 5.73 | train loss last: 5.74 | consumed tokens: 43909120 | grad norm avg: 0.73 | grad norm last: 0.89 |
# step: 675 | train samples/s: 8678.8 | train mfu: 0.08 | lr mean: 0.000191 | train loss avg: 5.74 | train loss last: 5.76 | consumed tokens: 44236800 | grad norm avg: 0.83 | grad norm last: 0.77 |
# step: 680 | train samples/s: 8697.7 | train mfu: 0.08 | lr mean: 0.000187 | train loss avg: 5.73 | train loss last: 5.77 | consumed tokens: 44564480 | grad norm avg: 0.77 | grad norm last: 0.74 |
# step: 685 | train samples/s: 8674.6 | train mfu: 0.08 | lr mean: 0.000183 | train loss avg: 5.71 | train loss last: 5.71 | consumed tokens: 44892160 | grad norm avg: 0.67 | grad norm last: 0.59 |
# step: 690 | train samples/s: 8677.4 | train mfu: 0.08 | lr mean: 0.000180 | train loss avg: 5.72 | train loss last: 5.65 | consumed tokens: 45219840 | grad norm avg: 0.69 | grad norm last: 0.65 |
# step: 695 | train samples/s: 8636.8 | train mfu: 0.08 | lr mean: 0.000176 | train loss avg: 5.72 | train loss last: 5.72 | consumed tokens: 45547520 | grad norm avg: 0.63 | grad norm last: 0.61 |
# step: 700 | train samples/s: 8640.7 | train mfu: 0.08 | lr mean: 0.000173 | train loss avg: 5.73 | train loss last: 5.72 | consumed tokens: 45875200 | grad norm avg: 0.66 | grad norm last: 0.71 |
# step: 705 | train samples/s: 8404.6 | train mfu: 0.07 | lr mean: 0.000169 | train loss avg: 5.72 | train loss last: 5.78 | consumed tokens: 46202880 | grad norm avg: 0.65 | grad norm last: 0.72 |
# step: 710 | train samples/s: 8352.2 | train mfu: 0.07 | lr mean: 0.000166 | train loss avg: 5.72 | train loss last: 5.74 | consumed tokens: 46530560 | grad norm avg: 0.68 | grad norm last: 0.69 |
# step: 715 | train samples/s: 8663.6 | train mfu: 0.08 | lr mean: 0.000162 | train loss avg: 5.71 | train loss last: 5.72 | consumed tokens: 46858240 | grad norm avg: 0.66 | grad norm last: 0.61 |
# step: 720 | train samples/s: 8698.3 | train mfu: 0.08 | lr mean: 0.000159 | train loss avg: 5.70 | train loss last: 5.69 | consumed tokens: 47185920 | grad norm avg: 0.66 | grad norm last: 0.61 |
# step: 725 | train samples/s: 8490.1 | train mfu: 0.07 | lr mean: 0.000156 | train loss avg: 5.72 | train loss last: 5.68 | consumed tokens: 47513600 | grad norm avg: 0.73 | grad norm last: 0.70 |
# step: 730 | train samples/s: 8673.7 | train mfu: 0.08 | lr mean: 0.000153 | train loss avg: 5.72 | train loss last: 5.69 | consumed tokens: 47841280 | grad norm avg: 0.69 | grad norm last: 0.76 |
# step: 735 | train samples/s: 8710.2 | train mfu: 0.08 | lr mean: 0.000149 | train loss avg: 5.71 | train loss last: 5.74 | consumed tokens: 48168960 | grad norm avg: 0.65 | grad norm last: 0.71 |
# step: 740 | train samples/s: 8603.2 | train mfu: 0.07 | lr mean: 0.000146 | train loss avg: 5.69 | train loss last: 5.68 | consumed tokens: 48496640 | grad norm avg: 0.65 | grad norm last: 0.66 |
# step: 745 | train samples/s: 8642.0 | train mfu: 0.08 | lr mean: 0.000143 | train loss avg: 5.75 | train loss last: 5.69 | consumed tokens: 48824320 | grad norm avg: 0.70 | grad norm last: 0.72 |
# step: 750 | train samples/s: 8687.8 | train mfu: 0.08 | lr mean: 0.000140 | train loss avg: 5.71 | train loss last: 5.73 | consumed tokens: 49152000 | grad norm avg: 0.68 | grad norm last: 0.87 |
# step: 755 | train samples/s: 8530.8 | train mfu: 0.07 | lr mean: 0.000137 | train loss avg: 5.71 | train loss last: 5.75 | consumed tokens: 49479680 | grad norm avg: 0.65 | grad norm last: 0.58 |
# step: 760 | train samples/s: 8517.3 | train mfu: 0.07 | lr mean: 0.000134 | train loss avg: 5.71 | train loss last: 5.73 | consumed tokens: 49807360 | grad norm avg: 0.70 | grad norm last: 0.67 |
# step: 765 | train samples/s: 8670.4 | train mfu: 0.08 | lr mean: 0.000131 | train loss avg: 5.71 | train loss last: 5.72 | consumed tokens: 50135040 | grad norm avg: 0.70 | grad norm last: 0.69 |
# step: 770 | train samples/s: 8679.5 | train mfu: 0.08 | lr mean: 0.000128 | train loss avg: 5.72 | train loss last: 5.74 | consumed tokens: 50462720 | grad norm avg: 0.60 | grad norm last: 0.61 |
# step: 775 | train samples/s: 8595.5 | train mfu: 0.07 | lr mean: 0.000125 | train loss avg: 5.70 | train loss last: 5.70 | consumed tokens: 50790400 | grad norm avg: 0.68 | grad norm last: 0.67 |
# step: 780 | train samples/s: 8624.8 | train mfu: 0.08 | lr mean: 0.000123 | train loss avg: 5.70 | train loss last: 5.70 | consumed tokens: 51118080 | grad norm avg: 0.62 | grad norm last: 0.65 |
# step: 785 | train samples/s: 8641.8 | train mfu: 0.08 | lr mean: 0.000120 | train loss avg: 5.67 | train loss last: 5.65 | consumed tokens: 51445760 | grad norm avg: 0.59 | grad norm last: 0.62 |
# step: 790 | train samples/s: 8652.1 | train mfu: 0.08 | lr mean: 0.000117 | train loss avg: 5.67 | train loss last: 5.70 | consumed tokens: 51773440 | grad norm avg: 0.63 | grad norm last: 0.67 |
# step: 795 | train samples/s: 8479.5 | train mfu: 0.07 | lr mean: 0.000115 | train loss avg: 5.70 | train loss last: 5.70 | consumed tokens: 52101120 | grad norm avg: 0.61 | grad norm last: 0.61 |
# step: 800 | train samples/s: 8548.8 | train mfu: 0.07 | lr mean: 0.000112 | train loss avg: 5.66 | train loss last: 5.63 | consumed tokens: 52428800 | grad norm avg: 0.67 | grad norm last: 0.66 |
# step: 805 | train samples/s: 8383.8 | train mfu: 0.07 | lr mean: 0.000110 | train loss avg: 5.70 | train loss last: 5.70 | consumed tokens: 52756480 | grad norm avg: 0.66 | grad norm last: 0.70 |
# step: 810 | train samples/s: 8300.1 | train mfu: 0.07 | lr mean: 0.000107 | train loss avg: 5.69 | train loss last: 5.69 | consumed tokens: 53084160 | grad norm avg: 0.63 | grad norm last: 0.54 |
# step: 815 | train samples/s: 8623.7 | train mfu: 0.07 | lr mean: 0.000105 | train loss avg: 5.72 | train loss last: 5.73 | consumed tokens: 53411840 | grad norm avg: 0.62 | grad norm last: 0.59 |
# step: 820 | train samples/s: 8627.4 | train mfu: 0.08 | lr mean: 0.000102 | train loss avg: 5.70 | train loss last: 5.70 | consumed tokens: 53739520 | grad norm avg: 0.68 | grad norm last: 0.70 |
# step: 825 | train samples/s: 8646.1 | train mfu: 0.08 | lr mean: 0.000100 | train loss avg: 5.68 | train loss last: 5.62 | consumed tokens: 54067200 | grad norm avg: 0.65 | grad norm last: 0.69 |
# step: 830 | train samples/s: 8676.2 | train mfu: 0.08 | lr mean: 0.000098 | train loss avg: 5.67 | train loss last: 5.68 | consumed tokens: 54394880 | grad norm avg: 0.62 | grad norm last: 0.50 |
# step: 835 | train samples/s: 8665.5 | train mfu: 0.08 | lr mean: 0.000096 | train loss avg: 5.67 | train loss last: 5.70 | consumed tokens: 54722560 | grad norm avg: 0.63 | grad norm last: 0.61 |
# step: 840 | train samples/s: 8304.7 | train mfu: 0.07 | lr mean: 0.000094 | train loss avg: 5.67 | train loss last: 5.64 | consumed tokens: 55050240 | grad norm avg: 0.58 | grad norm last: 0.56 |
# step: 845 | train samples/s: 8573.0 | train mfu: 0.07 | lr mean: 0.000092 | train loss avg: 5.71 | train loss last: 5.67 | consumed tokens: 55377920 | grad norm avg: 0.61 | grad norm last: 0.58 |
# step: 850 | train samples/s: 8618.5 | train mfu: 0.07 | lr mean: 0.000090 | train loss avg: 5.68 | train loss last: 5.70 | consumed tokens: 55705600 | grad norm avg: 0.61 | grad norm last: 0.70 |
# step: 855 | train samples/s: 8370.5 | train mfu: 0.07 | lr mean: 0.000088 | train loss avg: 5.67 | train loss last: 5.68 | consumed tokens: 56033280 | grad norm avg: 0.60 | grad norm last: 0.57 |
# step: 860 | train samples/s: 8618.5 | train mfu: 0.07 | lr mean: 0.000086 | train loss avg: 5.68 | train loss last: 5.66 | consumed tokens: 56360960 | grad norm avg: 0.61 | grad norm last: 0.59 |
# step: 865 | train samples/s: 8640.1 | train mfu: 0.08 | lr mean: 0.000084 | train loss avg: 5.70 | train loss last: 5.65 | consumed tokens: 56688640 | grad norm avg: 0.56 | grad norm last: 0.58 |
# step: 870 | train samples/s: 8615.8 | train mfu: 0.07 | lr mean: 0.000082 | train loss avg: 5.67 | train loss last: 5.66 | consumed tokens: 57016320 | grad norm avg: 0.59 | grad norm last: 0.63 |
# step: 875 | train samples/s: 8614.7 | train mfu: 0.07 | lr mean: 0.000081 | train loss avg: 5.66 | train loss last: 5.62 | consumed tokens: 57344000 | grad norm avg: 0.57 | grad norm last: 0.54 |
# step: 880 | train samples/s: 8647.5 | train mfu: 0.08 | lr mean: 0.000079 | train loss avg: 5.69 | train loss last: 5.68 | consumed tokens: 57671680 | grad norm avg: 0.58 | grad norm last: 0.59 |
# step: 885 | train samples/s: 8637.1 | train mfu: 0.08 | lr mean: 0.000077 | train loss avg: 5.68 | train loss last: 5.70 | consumed tokens: 57999360 | grad norm avg: 0.59 | grad norm last: 0.62 |
# step: 890 | train samples/s: 8637.1 | train mfu: 0.08 | lr mean: 0.000076 | train loss avg: 5.67 | train loss last: 5.70 | consumed tokens: 58327040 | grad norm avg: 0.64 | grad norm last: 0.58 |
# step: 895 | train samples/s: 8637.3 | train mfu: 0.08 | lr mean: 0.000075 | train loss avg: 5.68 | train loss last: 5.67 | consumed tokens: 58654720 | grad norm avg: 0.61 | grad norm last: 0.50 |
# step: 900 | train samples/s: 8648.7 | train mfu: 0.08 | lr mean: 0.000073 | train loss avg: 5.65 | train loss last: 5.65 | consumed tokens: 58982400 | grad norm avg: 0.58 | grad norm last: 0.60 |
# step: 905 | train samples/s: 8418.0 | train mfu: 0.07 | lr mean: 0.000072 | train loss avg: 5.68 | train loss last: 5.71 | consumed tokens: 59310080 | grad norm avg: 0.58 | grad norm last: 0.62 |
# step: 910 | train samples/s: 8624.5 | train mfu: 0.08 | lr mean: 0.000071 | train loss avg: 5.68 | train loss last: 5.69 | consumed tokens: 59637760 | grad norm avg: 0.62 | grad norm last: 0.63 |
# step: 915 | train samples/s: 8633.7 | train mfu: 0.08 | lr mean: 0.000070 | train loss avg: 5.66 | train loss last: 5.70 | consumed tokens: 59965440 | grad norm avg: 0.61 | grad norm last: 0.67 |
# step: 920 | train samples/s: 8639.7 | train mfu: 0.08 | lr mean: 0.000068 | train loss avg: 5.67 | train loss last: 5.67 | consumed tokens: 60293120 | grad norm avg: 0.60 | grad norm last: 0.59 |
# step: 925 | train samples/s: 8650.3 | train mfu: 0.08 | lr mean: 0.000067 | train loss avg: 5.68 | train loss last: 5.66 | consumed tokens: 60620800 | grad norm avg: 0.63 | grad norm last: 0.57 |
# step: 930 | train samples/s: 8664.4 | train mfu: 0.08 | lr mean: 0.000066 | train loss avg: 5.65 | train loss last: 5.64 | consumed tokens: 60948480 | grad norm avg: 0.60 | grad norm last: 0.61 |
# step: 935 | train samples/s: 8650.1 | train mfu: 0.08 | lr mean: 0.000066 | train loss avg: 5.66 | train loss last: 5.70 | consumed tokens: 61276160 | grad norm avg: 0.57 | grad norm last: 0.56 |
# step: 940 | train samples/s: 8657.4 | train mfu: 0.08 | lr mean: 0.000065 | train loss avg: 5.68 | train loss last: 5.65 | consumed tokens: 61603840 | grad norm avg: 0.58 | grad norm last: 0.56 |
# step: 945 | train samples/s: 8635.7 | train mfu: 0.08 | lr mean: 0.000064 | train loss avg: 5.68 | train loss last: 5.70 | consumed tokens: 61931520 | grad norm avg: 0.58 | grad norm last: 0.59 |
# step: 950 | train samples/s: 8669.1 | train mfu: 0.08 | lr mean: 0.000063 | train loss avg: 5.68 | train loss last: 5.71 | consumed tokens: 62259200 | grad norm avg: 0.58 | grad norm last: 0.61 |
# step: 955 | train samples/s: 8458.0 | train mfu: 0.07 | lr mean: 0.000063 | train loss avg: 5.69 | train loss last: 5.69 | consumed tokens: 62586880 | grad norm avg: 0.57 | grad norm last: 0.62 |
# step: 960 | train samples/s: 8617.6 | train mfu: 0.07 | lr mean: 0.000062 | train loss avg: 5.67 | train loss last: 5.70 | consumed tokens: 62914560 | grad norm avg: 0.57 | grad norm last: 0.55 |
# step: 965 | train samples/s: 8643.6 | train mfu: 0.08 | lr mean: 0.000062 | train loss avg: 5.65 | train loss last: 5.65 | consumed tokens: 63242240 | grad norm avg: 0.61 | grad norm last: 0.64 |
# step: 970 | train samples/s: 8546.9 | train mfu: 0.07 | lr mean: 0.000061 | train loss avg: 5.64 | train loss last: 5.66 | consumed tokens: 63569920 | grad norm avg: 0.58 | grad norm last: 0.55 |
# step: 975 | train samples/s: 8548.1 | train mfu: 0.07 | lr mean: 0.000061 | train loss avg: 5.67 | train loss last: 5.65 | consumed tokens: 63897600 | grad norm avg: 0.57 | grad norm last: 0.55 |
# step: 980 | train samples/s: 8636.5 | train mfu: 0.08 | lr mean: 0.000060 | train loss avg: 5.66 | train loss last: 5.65 | consumed tokens: 64225280 | grad norm avg: 0.54 | grad norm last: 0.53 |
# step: 985 | train samples/s: 8636.1 | train mfu: 0.08 | lr mean: 0.000060 | train loss avg: 5.65 | train loss last: 5.62 | consumed tokens: 64552960 | grad norm avg: 0.56 | grad norm last: 0.48 |
# step: 990 | train samples/s: 8670.1 | train mfu: 0.08 | lr mean: 0.000060 | train loss avg: 5.64 | train loss last: 5.65 | consumed tokens: 64880640 | grad norm avg: 0.59 | grad norm last: 0.56 |
# step: 995 | train samples/s: 8565.1 | train mfu: 0.07 | lr mean: 0.000060 | train loss avg: 5.68 | train loss last: 5.70 | consumed tokens: 65208320 | grad norm avg: 0.53 | grad norm last: 0.59 |
# step: 1000 | train samples/s: 8762.1 | train mfu: 0.08 | lr mean: 0.000060 | train loss avg: 5.65 | train loss last: 5.62 | consumed tokens: 65536000 | grad norm avg: 0.59 | grad norm last: 0.60 |
# Training done at 2024-09-06 16:15:44.074067.
# wandb: WARNING No program path found, not creating job artifact. See https://docs.wandb.ai/guides/launch/create-job
# wandb: - 0.090 MB of 0.090 MB uploaded
# wandb: Run history:
# wandb: train consumed tokens ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:   train grad norm avg █▆▄▄▁▃▂▃▃▄▆▄▅▄▄▅▄▄▅▄▄▃▃▄▄▃▄▃▃▃▃▃▃▂▂▃▂▂▂▂
# wandb:  train grad norm last ▅▅▃▅▁▃▃▁▂▄▃▅▆▃▄█▂▅▆▃▃▂▁▂▂▂▄▂▂▂▂▂▃▁▂▂▂▁▁▂
# wandb:         train lr mean ███████▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁
# wandb:  train train loss avg █▆▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: train train loss last █▆▄▄▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       train train mfu ▁████████████████████████████████▇██████
# wandb: train train samples/s ▁████████████████████████████████▇██████
# wandb:
# wandb: Run summary:
# wandb: train consumed tokens 65536000.0
# wandb:   train grad norm avg 0.58546
# wandb:  train grad norm last 0.59956
# wandb:         train lr mean 6e-05
# wandb:  train train loss avg 5.64531
# wandb: train train loss last 5.625
# wandb:       train train mfu 0.0762
# wandb: train train samples/s 8762.08105
# wandb:
# wandb: 🚀 View run 2024-09-06__16-14-48_7d9fc15e at: https://wandb.ai/modalities/ai_24_demo/runs/q1a14g30
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb_storage/wandb/run-20240906_161502-q1a14g30/logs
